# %% [markdown]
# ## Scraping an Iranian Sock Store
#
# This time we are going to work with APIs for web scraping!
#
# Store web address: [amoujurabi.ir](https://amoujurabi.ir)

# %%
import pandas as pd
from requests_html import HTMLSession

# %%
URL = 'https://www.zarin.express/api/v1/site/index?username=saniyasocks'
session = HTMLSession()

# %%
response = session.get(URL)
response.status_code
# Out:
# 200

# %%
response = response.json()
response
# Out:
# {'data': [{'id': 4998,
#    'title': 'اسپورت طرح پرچم(نوک مدادی)',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4998_1452306_1ee053b8-141c-67d6-bd0c-0242ac170002.jpg',
#    'type': 2,
#    'amount': 20000,
#    'amount_discount': 17000,
#    'discount': 15,
#    'inventory': 1,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4997,
#    'title': 'طرح پرچم اسپورت(آمریکا)',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4997_1452306_1ee053b1-def2-637c-84b1-0242ac170002.jpg',
#    'type': 2,
#    'amount': 27000,
#    'amount_discount': 24300,
#    'discount': 10,
#    'inventory': 2,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4996,
#    'title': 'سوها راه راه طوسی و قهوه ای',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4996_1452306_1ee053ac-7f85-689e-ad35-0242ac170002.jpg',
#    'type': 2,
#    'amount': 20000,
#    'amount_discount': 18000,
#    'discount': 10,
#    'inventory': 3,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4995,
#    'title': 'طرح پرچم اسپورت',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4995_1452306_1ee053a6-9421-6916-9ef4-0242ac170002.jpg',
#    'type': 2,
#    'amount': 25000,
#    'amount_discount': 20000,
#    'discount': 20,
#    'inventory': 2,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4994,
#    'title': 'سوها راه راه سفید و طوسی(اسپورت)',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4994_1452306_1ee0539f-c14d-6982-bbfc-0242ac170002.jpg',
#    'type': 2,
#    'amount': 20000,
#    'amount_discount': 18000,
#    'discount': 10,
#    'inventory': 3,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4993,
#    'title': 'اسپورت طرح پرچم طوسی',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4993_1452306_1ee0539a-14df-688a-ab8c-0242ac170002.jpg',
#    'type': 2,
#    'amount': 23000,
#    'amount_discount': 19550,
#    'discount': 15,
#    'inventory': 2,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4992,
#    'title': 'مچی مشکی طرح راه راه و خال خالی',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4992_1452306_1ee05394-40e4-6ab2-b17c-0242ac170002.jpg',
#    'type': 2,
#    'amount': 30000,
#    'amount_discount': 22500,
#    'discount': 25,
#    'inventory': 4,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4991,
#    'title': 'مچی طرح پرچم(آلمان)',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4991_1452306_1ee0538c-f185-6f7c-9eee-0242ac170002.jpg',
#    'type': 2,
#    'amount': 20000,
#    'amount_discount': 19200,
#    'discount': 4,
#    'inventory': 1,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4990,
#    'title': 'اسپورت سفید طرح گپ',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4990_1452306_1ee05387-bf56-6f60-9f29-0242ac170002.jpg',
#    'type': 2,
#    'amount': 15000,
#    'amount_discount': 15000,
#    'discount': 0,
#    'inventory': 4,
#    'unlimited': 0,
#    'invoice_count': -1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4989,
#    'title': 'دخترانه چهارخانه',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4989_1452306_1ee05381-2c02-6936-8e58-0242ac170002.jpg',
#    'type': 2,
#    'amount': 22000,
#    'amount_discount': 22000,
#    'discount': 0,
#    'inventory': 1,
#    'unlimited': 1,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4988,
#    'title': 'تا به تا طرح رخ رنگ زرد',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4988_1452306_1ee05376-d83f-610a-b248-0242ac170002.jpg',
#    'type': 2,
#    'amount': 25000,
#    'amount_discount': 20000,
#    'discount': 20,
#    'inventory': 1,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4987,
#    'title': 'طرح پرچم مشکی.خط سفید و سبز',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4987_1452306_1ee05371-7f61-6c36-834a-0242ac170002.jpg',
#    'type': 2,
#    'amount': 26000,
#    'amount_discount': 23400,
#    'discount': 10,
#    'inventory': 4,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4986,
#    'title': 'تا به تا طرح رخ رنگ کرم',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4986_1452306_1ee0536b-3645-6a30-8460-0242ac170002.jpg',
#    'type': 2,
#    'amount': 25000,
#    'amount_discount': 20000,
#    'discount': 20,
#    'inventory': 1,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4985,
#    'title': 'تابه تا طرح رخ',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4985_1452306_1ee05361-3dff-6a46-89dc-0242ac170002.jpg',
#    'type': 2,
#    'amount': 25000,
#    'amount_discount': 20000,
#    'discount': 20,
#    'inventory': 1,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4984,
#    'title': 'الوان ۳ سین',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4984_1452306_1ee0535b-4272-65de-b728-0242ac170002.jpg',
#    'type': 2,
#    'amount': 30000,
#    'amount_discount': 30000,
#    'discount': 0,
#    'inventory': 1,
#    'unlimited': 1,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4983,
#    'title': 'مشکی خط دار مچی',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4983_1452306_1ee0534e-cd8c-6532-b0e2-0242ac170002.jpg',
#    'type': 2,
#    'amount': 25000,
#    'amount_discount': 18750,
#    'discount': 25,
#    'inventory': 4,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4982,
#    'title': 'تا به تا طرح پاندا',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4982_1452306_1ee05349-1796-6872-a491-0242ac170002.jpg',
#    'type': 2,
#    'amount': 25000,
#    'amount_discount': 18750,
#    'discount': 25,
#    'inventory': 1,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4980,
#    'title': 'دخترانه طرح رنگین کمان',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4980_1452306_1ee0520f-dd88-66c4-b5ad-0242ac170002.jpg',
#    'type': 2,
#    'amount': 25000,
#    'amount_discount': 22000,
#    'discount': 12,
#    'inventory': -1,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4776,
#    'title': 'بنر تبلیغاتی عموجورابی',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4776_1452306_1edf1bf4-ad7f-6876-a361-0242ac170002.jpg',
#    'type': 2,
#    'amount': 5,
#    'amount_discount': 5,
#    'discount': 0,
#    'inventory': -1,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0},
#   {'id': 4775,
#    'title': 'جوراب مشکی تک رنگ نیم ساق',
#    'image': 'https://file.zarin.express/uploads/products/img_product_0_product_4775_1452306_1edf1b0d-6dd9-67c2-bdc9-0242ac170002.jpg',
#    'type': 2,
#    'amount': 27000,
#    'amount_discount': 25110,
#    'discount': 7,
#    'inventory': 16,
#    'unlimited': 0,
#    'invoice_count': 1,
#    'status': 1,
#    'status_text': 'فعال',
#    'views': 0}],
#  'meta': {'count': 60,
#   'limit': 20,
#   'current_page': 1,
#   'next_page': 2,
#   'last_page': 3,
#   'previous_page': None}}

# %%
last_page = response['meta']['last_page']
last_page
# Out:
# 3

# %%
products = []

for i in range(1, last_page+1):
    print(f'Scraping page {i}...')
    response = session.get(f'{URL}&page={i}')
    products_ = response.json()['data']

    for product in products_:
        products.append({
            'Title': product['title'],
            'Image': product['image'],
            'Amount': product['amount'],  # Price
            'Amount_Discount': product['amount_discount'],
        })
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...

# %%
products
# Out:
# [{'Title': 'اسپورت طرح پرچم(نوک مدادی)',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4998_1452306_1ee053b8-141c-67d6-bd0c-0242ac170002.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 17000},
#  {'Title': 'طرح پرچم اسپورت(آمریکا)',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4997_1452306_1ee053b1-def2-637c-84b1-0242ac170002.jpg',
#   'Amount': 27000,
#   'Amount_Discount': 24300},
#  {'Title': 'سوها راه راه طوسی و قهوه ای',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4996_1452306_1ee053ac-7f85-689e-ad35-0242ac170002.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 18000},
#  {'Title': 'طرح پرچم اسپورت',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4995_1452306_1ee053a6-9421-6916-9ef4-0242ac170002.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 20000},
#  {'Title': 'سوها راه راه سفید و طوسی(اسپورت)',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4994_1452306_1ee0539f-c14d-6982-bbfc-0242ac170002.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 18000},
#  {'Title': 'اسپورت طرح پرچم طوسی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4993_1452306_1ee0539a-14df-688a-ab8c-0242ac170002.jpg',
#   'Amount': 23000,
#   'Amount_Discount': 19550},
#  {'Title': 'مچی مشکی طرح راه راه و خال خالی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4992_1452306_1ee05394-40e4-6ab2-b17c-0242ac170002.jpg',
#   'Amount': 30000,
#   'Amount_Discount': 22500},
#  {'Title': 'مچی طرح پرچم(آلمان)',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4991_1452306_1ee0538c-f185-6f7c-9eee-0242ac170002.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 19200},
#  {'Title': 'اسپورت سفید طرح گپ',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4990_1452306_1ee05387-bf56-6f60-9f29-0242ac170002.jpg',
#   'Amount': 15000,
#   'Amount_Discount': 15000},
#  {'Title': 'دخترانه چهارخانه',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4989_1452306_1ee05381-2c02-6936-8e58-0242ac170002.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 22000},
#  {'Title': 'تا به تا طرح رخ رنگ زرد',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4988_1452306_1ee05376-d83f-610a-b248-0242ac170002.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 20000},
#  {'Title': 'طرح پرچم مشکی.خط سفید و سبز',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4987_1452306_1ee05371-7f61-6c36-834a-0242ac170002.jpg',
#   'Amount': 26000,
#   'Amount_Discount': 23400},
#  {'Title': 'تا به تا طرح رخ رنگ کرم',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4986_1452306_1ee0536b-3645-6a30-8460-0242ac170002.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 20000},
#  {'Title': 'تابه تا طرح رخ',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4985_1452306_1ee05361-3dff-6a46-89dc-0242ac170002.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 20000},
#  {'Title': 'الوان ۳ سین',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4984_1452306_1ee0535b-4272-65de-b728-0242ac170002.jpg',
#   'Amount': 30000,
#   'Amount_Discount': 30000},
#  {'Title': 'مشکی خط دار مچی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4983_1452306_1ee0534e-cd8c-6532-b0e2-0242ac170002.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 18750},
#  {'Title': 'تا به تا طرح پاندا',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4982_1452306_1ee05349-1796-6872-a491-0242ac170002.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 18750},
#  {'Title': 'دخترانه طرح رنگین کمان',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4980_1452306_1ee0520f-dd88-66c4-b5ad-0242ac170002.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 22000},
#  {'Title': 'بنر تبلیغاتی عموجورابی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4776_1452306_1edf1bf4-ad7f-6876-a361-0242ac170002.jpg',
#   'Amount': 5,
#   'Amount_Discount': 5},
#  {'Title': 'جوراب مشکی تک رنگ نیم ساق',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4775_1452306_1edf1b0d-6dd9-67c2-bdc9-0242ac170002.jpg',
#   'Amount': 27000,
#   'Amount_Discount': 25110},
#  {'Title': 'کالج اسپورت(پشت ژله ای)',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4774_1452306_1edf1b06-a520-62e6-9af9-0242ac170002.jpg',
#   'Amount': 23000,
#   'Amount_Discount': 23000},
#  {'Title': 'رنگین کمان دخترانه فانتزی طرح خرسی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4773_1452306_1edf1a74-c87b-63cc-916e-0242ac170002.jpg',
#   'Amount': 27000,
#   'Amount_Discount': 27000},
#  {'Title': 'اسپورت مچی.آقا و خانم',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4772_1452306_1edf1a6a-3c4f-643e-96f1-0242ac170002.jpg',
#   'Amount': 32000,
#   'Amount_Discount': 32000},
#  {'Title': 'رنگین کمان راه راه طرح تدی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4771_1452306_1edf1a5a-0f41-6fce-9512-0242ac170002.jpg',
#   'Amount': 27000,
#   'Amount_Discount': 27000},
#  {'Title': 'دخترانه مچی طرح میلک',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4740_1452306_1edede9c-f14f-619a-b52f-0242ac170002.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 22000},
#  {'Title': 'اسپورت طرح پرچم',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4739_1452306_1ededd3f-a8d0-6846-8039-0242ac170002.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 22000},
#  {'Title': 'مچی فانتزی طرح قلب',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4734_1452306_1eded202-e4cc-6ea0-9426-0242ac170002.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 22000},
#  {'Title': 'پارازین زنانه دوربع کفه دار',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4463_1452306_1eddc8fd-d909-6dfc-b76c-0242ac160003.jpg',
#   'Amount': 15000,
#   'Amount_Discount': 15000},
#  {'Title': 'پارازین دوربع کفه دار',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_1_product_4424_1452306_1eddbb7f-f1d2-6ae0-b86a-0242ac160003.jpg',
#   'Amount': 17000,
#   'Amount_Discount': 17000},
#  {'Title': 'کالج اسپورت کودک.یک و دو سال',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4410_1452306_1edda38a-2ca6-6080-9b3c-0242ac160003.jpg',
#   'Amount': 19000,
#   'Amount_Discount': 19000},
#  {'Title': 'اسپورت مچی طرح آدیداس',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4409_1452306_1edda383-39d3-6ed0-85ca-0242ac160003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'ساق دست',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4408_1452306_1edda37b-fe86-6ece-8de4-0242ac160003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'پارازین شیشه ای کفه دار',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4404_1452306_1edda357-6d57-667a-829b-0242ac160003.jpg',
#   'Amount': 12500,
#   'Amount_Discount': 12500},
#  {'Title': 'زنانه مچی طرح موشی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4393_1452306_1edd8833-7281-62ca-90a4-0242ac160003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'زنانه مچی طرح موشی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4392_1452306_1edd882f-6b4c-6fd0-8e2d-0242ac160003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'زنانه مچی طرح موشی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4391_1452306_1edd8827-57f0-6c5a-a460-0242ac160003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'نیم ساق اسپورت ٱیدین طرح فیلا',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4125_1452306_1edbabeb-4fc7-6bba-9de1-0242ac160003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'مچی اسپورت آیدین طرح دیزل',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4124_1452306_1edbabe2-6fac-66dc-b376-0242ac160003.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 22000},
#  {'Title': 'مچی سفید برند سوها',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4122_1452306_1edbabd6-032f-6286-809b-0242ac160003.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 20460},
#  {'Title': 'پاپوش زنانه طرح سنتی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4069_1452306_1edb7858-6db2-6d58-8cf3-0242ac160003.jpg',
#   'Amount': 25000,
#   'Amount_Discount': 25000},
#  {'Title': 'مردانه سفید طرح اسکاچ',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_4067_1452306_1edb784b-2832-6ae2-b571-0242ac160003.jpg',
#   'Amount': 300000,
#   'Amount_Discount': 300000},
#  {'Title': 'مچی فانتزی دخترانه',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3968_1452306_1edaee4d-6da1-6642-a35f-0242ac160003.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 22000},
#  {'Title': 'مچی مشکی طرح ستاره',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3822_1452306_1eda255a-a130-6bfa-8635-0242ac130003.jpg',
#   'Amount': 17000,
#   'Amount_Discount': 17000},
#  {'Title': 'فانتزی مچی طرح خرس',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3821_1452306_1eda2553-94b9-6dd8-9e9b-0242ac130003.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 19800},
#  {'Title': 'دخترانه فانتزی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3721_1452306_1ed9f4c2-301b-6da2-b5a6-0242ac130003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'مچی اسپورت طرح BTS',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3720_1452306_1ed9f4bb-0f43-6668-be17-0242ac130003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'اسپورت مچی مشکی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3719_1452306_1ed9f4b5-461b-618c-b97f-0242ac130003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'کالج طرح پرچم. اسپورت',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3641_1452306_1ed999e5-45e5-6972-bcb0-0242ac130003.jpg',
#   'Amount': 135000,
#   'Amount_Discount': 135000},
#  {'Title': 'دخترانه چارخانه طرح خرسی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3629_1452306_1ed967f4-ab66-679c-955e-0242ac130003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'فانتزی مچی طرح ستاره',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3628_1452306_1ed967ef-4599-663a-bd38-0242ac130003.jpg',
#   'Amount': 15000,
#   'Amount_Discount': 15000},
#  {'Title': 'مچی چهار خونه طرح خرسی',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3627_1452306_1ed964bc-dec7-68f6-ba12-0242ac130003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 18800},
#  {'Title': 'مچی طرح ریبوک',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3613_1452306_1ed93ef6-de5c-6b46-891e-0242ac130003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'مچی طرح آدیداس راه راه',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3612_1452306_1ed93ede-124c-6ef6-a04f-0242ac130003.jpg',
#   'Amount': 18000,
#   'Amount_Discount': 18000},
#  {'Title': 'دخترانه فانتزی طرح لاو',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3610_1452306_1ed93ec5-dfc5-68b0-889e-0242ac130003.jpg',
#   'Amount': 18000,
#   'Amount_Discount': 18000},
#  {'Title': 'راه راه الوان',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3514_1452306_1ed8bf44-e8f7-6376-8915-0242ac120003.jpg',
#   'Amount': 27000,
#   'Amount_Discount': 24840},
#  {'Title': 'کالج اسپورت',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3493_1452306_1ed882a7-49dc-6f90-9328-0242ac120003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 17000},
#  {'Title': 'پاپوش الوان',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3469_1452306_1ed85acd-f977-62cc-97d6-0242ac120003.jpg',
#   'Amount': 20000,
#   'Amount_Discount': 20000},
#  {'Title': 'مچی اسپورت طرح ایکس',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3456_1452306_1edede92-f764-6044-8dbd-0242ac170002.jpg',
#   'Amount': 22000,
#   'Amount_Discount': 22000},
#  {'Title': 'قایقی بلند',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3444_1452306_1ed8529c-0ce8-6cc8-8f9f-0242ac120003.jpg',
#   'Amount': 12000,
#   'Amount_Discount': 12000},
#  {'Title': 'مچی طرح دار',
#   'Image': 'https://file.zarin.express/uploads/products/img_product_0_product_3405_1452306_1ed80bed-2a9a-6492-8659-0242ac120003.jpg',
#   'Amount': 27000,
#   'Amount_Discount': 24300}]

# %%
df = pd.DataFrame(products)
df.sample(10)
# Out:
#                            Title
# 44                دخترانه فانتزی  \
# 39          پاپوش زنانه طرح سنتی
# 19     جوراب مشکی تک رنگ نیم ساق
# 31                       ساق دست
# 59                   مچی طرح دار
# 28         پارازین دوربع کفه دار
# 20       کالج اسپورت(پشت ژله ای)
# 41            مچی فانتزی دخترانه
# 40         مردانه سفید طرح اسکاچ
# 29  کالج اسپورت کودک.یک و دو سال
#
#                                                 Image  Amount  Amount_Discount
# 44  https://file.zarin.express/uploads/products/im...   20000            20000
# 39  https://file.zarin.express/uploads/products/im...   25000            25000
# 19  https://file.zarin.express/uploads/products/im...   27000            25110
# 31  https://file.zarin.express/uploads/products/im...   20000            20000
# 59  https://file.zarin.express/uploads/products/im...   27000            24300
# 28  https://file.zarin.express/uploads/products/im...   17000            17000
# 20  https://file.zarin.express/uploads/products/im...   23000            23000
# 41  https://file.zarin.express/uploads/products/im...   22000            22000
# 40  https://file.zarin.express/uploads/products/im...  300000           300000
# 29  https://file.zarin.express/uploads/products/im...   19000            19000

# %%
df.to_csv('./exports/amoujurabi_socks.csv', index=False)
